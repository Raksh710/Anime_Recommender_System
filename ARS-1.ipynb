# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
df1 = pd.read_csv('anime.csv')
df1
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df1.isna().sum()
# Out:
# MAL_ID           0
# Name             0
# Score            0
# Genres           0
# English name     0
# Japanese name    0
# Type             0
# Episodes         0
# Aired            0
# Premiered        0
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Duration         0
# Rating           0
# Ranked           0
# Popularity       0
# Members          0
# Favorites        0
# Watching         0
# Completed        0
# On-Hold          0
# Dropped          0
# Plan to Watch    0
# Score-10         0
# Score-9          0
# Score-8          0
# Score-7          0
# Score-6          0
# Score-5          0
# Score-4          0
# Score-3          0
# Score-2          0
# Score-1          0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
#        'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1'],
#       dtype='object')

# %%
df1.drop(['English name', 'Japanese name'],axis=1,inplace=True)

# %%
df2 = pd.read_csv('anime_with_synopsis.csv')
df2
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df = pd.merge(left=df1,right=df2,on=['MAL_ID','Name','Score','Genres'],how='inner')

# %%
df
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres   Type Episodes  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                  Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# ...

# %%
df.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'On-Hold', 'Dropped', 'Plan to Watch', 'Score-10',
#        'Score-9', 'Score-8', 'Score-7', 'Score-6', 'Score-5', 'Score-4',
#        'Score-3', 'Score-2', 'Score-1', 'sypnopsis'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.drop(['Score-10','Score-9', 'Score-8', 'Score-7', 'Score-6', 'Score-5', 'Score-4','Score-3', 'Score-2', 'Score-1'], axis=1, inplace=True)

# %%
df2.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'On-Hold', 'Dropped', 'Plan to Watch', 'sypnopsis'],
#       dtype='object')

# %%
df2
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres   Type Episodes  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                  Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# ...

# %%
df2.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'On-Hold', 'Dropped', 'Plan to Watch', 'sypnopsis'],
#       dtype='object')

# %%
df3 = df2.drop(['On-Hold', 'Dropped', 'Plan to Watch'],axis=1).copy()

# %%
df3
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres   Type Episodes  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1                  Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# ...

# %%
def summary_gen(cols):
    genres = cols[0]
    sy = cols[1]
    return f"Genre: {genres} and the synopsis is {sy}"

# %%
df3.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'sypnopsis'],
#       dtype='object')

# %%
df3['summary'] = df3[['Genres','sypnopsis']].apply(summary_gen,axis=1)

# %%
df3[['Genres', 'sypnopsis', 'summary']]
# Out:
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 16209                   Adventure, Mystery, Supernatural
# 16210                       Comedy, Horror, Supernatural
# 16211  Mystery, Dementia, Horror, Psychological, Supe...
# 16212                   Adventure, Slice of Life, Comedy
# 16213                                    Action, Fantasy
#
#                                                sypnopsis  \
# 0      In the year 2071, humanity has colonized sever...
# 1      other day, another bounty—such is the life of ...
# 2      Vash the Stampede is the man with a $$60,000,0...
# ...

# %%
#df3.drop(['Genres','sypnopsis'],axis=1,inplace=True)

# %%
df3.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'sypnopsis', 'summary'],
#       dtype='object')

# %%
df3.sort_values('Ranked')['Name']
# Out:
# 16200                              The Sun, Moon and Stars
# 15444                Koukaku Kidoutai: SAC_2045 2nd Season
# 3446                      Fullmetal Alchemist: Brotherhood
# 11735                           3-gatsu no Lion 2nd Season
# 10091    JoJo no Kimyou na Bouken Part 4: Diamond wa Ku...
#                                ...
# 15877         Osananajimi ga Zettai ni Makenai Love Comedy
# 14951                     Utawarerumono: Futari no Hakuoro
# 7338                                              Aoki Uru
# 16212                          Yama no Susume: Next Summit
# 16213                                        Scarlet Nexus
# Name: Name, Length: 16214, dtype: object

# %% [markdown]
# ## Let's get only popular anime

# %%
df3.sort_values('Popularity',ascending=False)['Name']
# Out:
# 16212              Yama no Susume: Next Summit
# 16207              Tsuki to Laika to Nosferatu
# 16213                            Scarlet Nexus
# 16210                             Mieruko-chan
# 16205                            Kyoukai Senki
#                          ...
# 3446          Fullmetal Alchemist: Brotherhood
# 6550                        Shingeki no Kyojin
# 1336                                Death Note
# 16200                  The Sun, Moon and Stars
# 15444    Koukaku Kidoutai: SAC_2045 2nd Season
# Name: Name, Length: 16214, dtype: object

# %%
df3.sort_values('Members',ascending=False)[['Name','Members']]
# Out:
#                                         Name  Members
# 1336                              Death Note  2589552
# 6550                      Shingeki no Kyojin  2531397
# 3446        Fullmetal Alchemist: Brotherhood  2248456
# 5787                        Sword Art Online  2214395
# 9394                           One Punch Man  2123866
# ...                                      ...      ...
# 16169            Kamen Senshi Lavithunder CM       25
# 16168                        Chickip Dancers       25
# 16142                       Ye Xing Xia Ying       21
# 15444  Koukaku Kidoutai: SAC_2045 2nd Season        1
# 16200                The Sun, Moon and Stars        1
#
# [16214 rows x 2 columns]

# %%
df3.sort_values('Members',ascending=False)[['Name','Members']].head(50)
# Out:
#                                          Name  Members
# 1336                               Death Note  2589552
# 6550                       Shingeki no Kyojin  2531397
# 3446         Fullmetal Alchemist: Brotherhood  2248456
# 5787                         Sword Art Online  2214395
# 9394                            One Punch Man  2123866
# 10097                   Boku no Hero Academia  1909814
# 7674                              Tokyo Ghoul  1895488
# 10                                     Naruto  1830540
# 4953                              Steins;Gate  1771162
# 7206                          No Game No Life  1751054
# 10213                          Kimi no Na wa.  1726660
# 5660                   Hunter x Hunter (2011)  1673924
# 10796        Boku no Hero Academia 2nd Season  1611771
# 3981                             Angel Beats!  1591773
# 8371              Shingeki no Kyojin Season 2  1591506
# 1373          Code Geass: Hangyaku no Lelouch  1583882
# ...

# %%
df3['Members'].describe()
# Out:
# count    1.621400e+04
# mean     3.709850e+04
# std      1.300729e+05
# min      1.000000e+00
# 25%      3.030000e+02
# 50%      1.773500e+03
# 75%      1.554000e+04
# max      2.589552e+06
# Name: Members, dtype: float64

# %%
df3['Members'].median()
# Out:
# 1773.5

# %%
df_popular_anime = df3[df3['Members'] >= df3['Members'].median()].copy()

# %%
df_popular_anime
# Out:
#        MAL_ID                                               Name    Score  \
# 0           1                                       Cowboy Bebop     8.78
# 1           5                    Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                                             Trigun     8.24
# 3           7                                 Witch Hunter Robin     7.27
# 4           8                                     Bouken Ou Beet     6.98
# ...       ...                                                ...      ...
# 16201   48438  Mahoutsukai no Yome: Nishi no Shounen to Seira...  Unknown
# 16204   48456                                SK∞: Crazy Rock Jam     6.52
# 16207   48471                        Tsuki to Laika to Nosferatu  Unknown
# 16210   48483                                       Mieruko-chan  Unknown
# 16211   48488                    Higurashi no Naku Koro ni Sotsu  Unknown
#
#                                                   Genres     Type Episodes  \
# ...

# %%
df_popular_anime.sort_values('Members',ascending=False)[['Name','Members','Genres','Ranked']].head(20)
# Out:
#                                    Name  Members  \
# 1336                         Death Note  2589552
# 6550                 Shingeki no Kyojin  2531397
# 3446   Fullmetal Alchemist: Brotherhood  2248456
# 5787                   Sword Art Online  2214395
# 9394                      One Punch Man  2123866
# 10097             Boku no Hero Academia  1909814
# 7674                        Tokyo Ghoul  1895488
# 10                               Naruto  1830540
# 4953                        Steins;Gate  1771162
# 7206                    No Game No Life  1751054
# 10213                    Kimi no Na wa.  1726660
# 5660             Hunter x Hunter (2011)  1673924
# 10796  Boku no Hero Academia 2nd Season  1611771
# 3981                       Angel Beats!  1591773
# 8371        Shingeki no Kyojin Season 2  1591506
# 1373    Code Geass: Hangyaku no Lelouch  1583882
# 3147                          Toradora!  1567792
# 1508                 Naruto: Shippuuden  1543765
# ...

# %%
df_popular_anime.sort_values('Members',ascending=False)[['Name','Members','Genres','Ranked']].head(20)['Genres'].value_counts()
# Out:
# Action, Adventure, Comedy, Super Power, Martial Arts, Shounen          2
# Action, Military, Mystery, Super Power, Drama, Fantasy, Shounen        2
# Mystery, Police, Psychological, Supernatural, Thriller, Shounen        1
# Romance, Supernatural, School, Drama                                   1
# Action, Adventure, Comedy, Supernatural, Shounen                       1
# Slice of Life, Comedy, Romance, School                                 1
# Action, Military, Sci-Fi, Super Power, Drama, Mecha, School            1
# Action, Comedy, Drama, School, Supernatural                            1
# Action, Comedy, Super Power, School, Shounen                           1
# Action, Adventure, Fantasy, Shounen, Super Power                       1
# Game, Adventure, Comedy, Supernatural, Ecchi, Fantasy                  1
# Thriller, Sci-Fi                                                       1
# Action, Mystery, Horror, Psychological, Supernatural, Drama, Seinen    1
# ...

# %% [markdown]
# # Calculating the number of tokens

# %%
import tiktoken

# %%
def num_tokesns_from_string(string, encoding_name):
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokesns_from_string(string = df_popular_anime['summary'][0],encoding_name = 'cl100k_base') # name of encoding used by Open AI cl100k_base
# Out:
# 239

# %%
len(df_popular_anime['summary'][0].split()) # number of words
# Out:
# 180

# %%
df_popular_anime['token_counts'] = df_popular_anime['summary'].apply(lambda x: num_tokesns_from_string(string=x,encoding_name="cl100k_base"))

# %%
def unknown_changer(x):
    if x=='Unknown':
        return 0
    else:
        return np.float64(x)

# %%
df_popular_anime['Score'] = df_popular_anime['Score'].apply(lambda x: unknown_changer(x))

# %%
df_popular_anime['Score'].value_counts()
# Out:
# 0.00    268
# 7.27     54
# 6.65     52
# 7.28     52
# 6.52     51
#        ...
# 4.59      1
# 3.15      1
# 3.23      1
# 3.26      1
# 3.89      1
# Name: Score, Length: 485, dtype: int64

# %%
df_popular_anime.sort_values('Score',ascending=False).head(20)
# Out:
#        MAL_ID                                               Name  Score  \
# 3446     5114                   Fullmetal Alchemist: Brotherhood   9.19
# 14647   40028               Shingeki no Kyojin: The Final Season   9.17
# 4953     9253                                        Steins;Gate   9.11
# 5660    11061                             Hunter x Hunter (2011)   9.10
# 8879    28977                                           Gintama°   9.10
# 13720   38524                 Shingeki no Kyojin Season 3 Part 2   9.10
# 5234     9969                                           Gintama'   9.08
# 723       820                               Ginga Eiyuu Densetsu   9.07
# 6377    15417                                Gintama': Enchousen   9.04
# 8854    28851                                     Koe no Katachi   9.00
# 11735   35180                         3-gatsu no Lion 2nd Season   9.00
# 11109   34096                                           Gintama.   8.99
# ...

# %%
df_popular_anime['token_counts'].sum()
# Out:
# 1045494

# %% [markdown]
# # Ada model (currently the best for text embedding) costs USD 0.0004 per 1K tokens. It gives embedding in 1536 dimensions

# %%
(df_popular_anime['token_counts'].sum()/1000) * 0.0004
# Out:
# 0.4181976

# %%
import openai, os

# %% [markdown]
# # Already created embeddings using openAI's API

# %%
df_popular_anime = pd.read_csv('Popular_Anime_with_embeddings.csv')
df_popular_anime
# Out:
#       MAL_ID                                               Name  Score  \
# 0          1                                       Cowboy Bebop   8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira   8.39
# 2          6                                             Trigun   8.24
# 3          7                                 Witch Hunter Robin   7.27
# 4          8                                     Bouken Ou Beet   6.98
# ...      ...                                                ...    ...
# 8102   48438  Mahoutsukai no Yome: Nishi no Shounen to Seira...   0.00
# 8103   48456                                SK∞: Crazy Rock Jam   6.52
# 8104   48471                        Tsuki to Laika to Nosferatu   0.00
# 8105   48483                                       Mieruko-chan   0.00
# 8106   48488                    Higurashi no Naku Koro ni Sotsu   0.00
#
#                                                  Genres     Type Episodes  \
# ...

# %%
df_popular_anime.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'sypnopsis', 'summary', 'token_counts', 'embedding'],
#       dtype='object')

# %%
df_popular_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8107 entries, 0 to 8106
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MAL_ID        8107 non-null   int64
#  1   Name          8107 non-null   object
#  2   Score         8107 non-null   float64
#  3   Genres        8107 non-null   object
#  4   Type          8107 non-null   object
#  5   Episodes      8107 non-null   object
#  6   Aired         8107 non-null   object
#  7   Premiered     8107 non-null   object
#  8   Producers     8107 non-null   object
#  9   Licensors     8107 non-null   object
#  10  Studios       8107 non-null   object
#  11  Source        8107 non-null   object
#  12  Duration      8107 non-null   object
#  13  Rating        8107 non-null   object
#  14  Ranked        8107 non-null   object
#  15  Popularity    8107 non-null   int64
#  16  Members       8107 non-null   int64
#  17  Favorites     8107 non-null   int64
# ...

# %%
 df_popular_anime['Score'].value_counts()
# Out:
# 0.00    268
# 7.27     54
# 6.65     52
# 7.28     52
# 6.52     51
#        ...
# 4.59      1
# 3.15      1
# 3.23      1
# 3.26      1
# 3.89      1
# Name: Score, Length: 485, dtype: int64

# %%
# getting all the required values
v = df_popular_anime['Popularity']
R = df_popular_anime['Score']
C = df_popular_anime['Score'].mean()
m = df_popular_anime['Score'].quantile(0.70) # only those samples whose 'score' is more than 70 percentile (by value)

# %%
df_popular_anime['weighted_average'] = ((R*v) + (C*m))/ (v+m) # using the formula of weighted average

# %%
df_popular_anime
# Out:
#       MAL_ID                                               Name  Score  \
# 0          1                                       Cowboy Bebop   8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira   8.39
# 2          6                                             Trigun   8.24
# 3          7                                 Witch Hunter Robin   7.27
# 4          8                                     Bouken Ou Beet   6.98
# ...      ...                                                ...    ...
# 8102   48438  Mahoutsukai no Yome: Nishi no Shounen to Seira...   0.00
# 8103   48456                                SK∞: Crazy Rock Jam   6.52
# 8104   48471                        Tsuki to Laika to Nosferatu   0.00
# 8105   48483                                       Mieruko-chan   0.00
# 8106   48488                    Higurashi no Naku Koro ni Sotsu   0.00
#
#                                                  Genres     Type Episodes  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler() # creating scaling function rating

# %%
df_popular_anime.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'sypnopsis', 'summary', 'token_counts', 'embedding',
#        'weighted_average'],
#       dtype='object')

# %%
animes_scaled_df = sc.fit_transform(df_popular_anime[['weighted_average','Members']]) # fit and transforming the required columns
animes_scaled_df = pd.DataFrame(df_popular_anime, columns=['weighted_average','Members']) # creating a new dataframe
animes_scaled_df.head() # checking the scaled dataframe
# Out:
#    weighted_average  Members
# 0          8.443896  1251960
# 1          8.365793   273145
# 2          8.184192   558913
# 3          7.266906    94683
# 4          6.979440    13224

# %%
df_popular_anime['normalized_weight'] = animes_scaled_df['weighted_average'] 
df_popular_anime['normalized_members'] = animes_scaled_df['Members']

# %%
# evaluating the score giving 50% prefernce to normalized weight and 50% to normalized memebers
df_popular_anime['weighted_score'] = df_popular_anime['normalized_weight'] * 0.5 + df_popular_anime['normalized_members'] * 0.5

# %%
df_popular_anime
# Out:
#       MAL_ID                                               Name  Score  \
# 0          1                                       Cowboy Bebop   8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira   8.39
# 2          6                                             Trigun   8.24
# 3          7                                 Witch Hunter Robin   7.27
# 4          8                                     Bouken Ou Beet   6.98
# ...      ...                                                ...    ...
# 8102   48438  Mahoutsukai no Yome: Nishi no Shounen to Seira...   0.00
# 8103   48456                                SK∞: Crazy Rock Jam   6.52
# 8104   48471                        Tsuki to Laika to Nosferatu   0.00
# 8105   48483                                       Mieruko-chan   0.00
# 8106   48488                    Higurashi no Naku Koro ni Sotsu   0.00
#
#                                                  Genres     Type Episodes  \
# ...

# %%
english_name = pd.read_csv('anime.csv')
english_name = english_name[['Name','English name']].copy()

# %%
english_name
# Out:
#                                   Name                     English name
# 0                         Cowboy Bebop                     Cowboy Bebop
# 1      Cowboy Bebop: Tengoku no Tobira           Cowboy Bebop:The Movie
# 2                               Trigun                           Trigun
# 3                   Witch Hunter Robin               Witch Hunter Robin
# 4                       Bouken Ou Beet           Beet the Vandel Buster
# ...                                ...                              ...
# 17557  Daomu Biji Zhi Qinling Shen Shu                          Unknown
# 17558                     Mieruko-chan                          Unknown
# 17559  Higurashi no Naku Koro ni Sotsu  Higurashi:When They Cry – SOTSU
# 17560      Yama no Susume: Next Summit                          Unknown
# 17561                    Scarlet Nexus                          Unknown
#
# [17562 rows x 2 columns]

# %%
df_popular_anime_full = pd.merge(left=df_popular_anime,right=english_name,how='left',on='Name')

# %%
df_popular_anime_full
# Out:
#       MAL_ID                                               Name  Score  \
# 0          1                                       Cowboy Bebop   8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira   8.39
# 2          6                                             Trigun   8.24
# 3          7                                 Witch Hunter Robin   7.27
# 4          8                                     Bouken Ou Beet   6.98
# ...      ...                                                ...    ...
# 8109   48438  Mahoutsukai no Yome: Nishi no Shounen to Seira...   0.00
# 8110   48456                                SK∞: Crazy Rock Jam   6.52
# 8111   48471                        Tsuki to Laika to Nosferatu   0.00
# 8112   48483                                       Mieruko-chan   0.00
# 8113   48488                    Higurashi no Naku Koro ni Sotsu   0.00
#
#                                                  Genres     Type Episodes  \
# ...

# %%
df_popular_anime_full['weighted_score'].describe()
# Out:
# count    8.114000e+03
# mean     3.690076e+04
# std      8.826276e+04
# min      8.900902e+02
# 25%      2.427663e+03
# 50%      7.779420e+03
# 75%      2.966236e+04
# max      1.294779e+06
# Name: weighted_score, dtype: float64

# %%
df_popular_anime_full_2 = df_popular_anime_full[df_popular_anime_full['weighted_score'] > df_popular_anime_full['weighted_score'].median()].copy()

# %%
df_popular_anime_full_2.sort_values('weighted_score',ascending=False).head(50)[['Name','English name','weighted_score']]
# Out:
#                                         Name  \
# 1307                              Death Note
# 4481                      Shingeki no Kyojin
# 2817        Fullmetal Alchemist: Brotherhood
# 4007                        Sword Art Online
# 5472                           One Punch Man
# 5794                   Boku no Hero Academia
# 4968                             Tokyo Ghoul
# 10                                    Naruto
# 3555                             Steins;Gate
# 4749                         No Game No Life
# 5852                          Kimi no Na wa.
# 3933                  Hunter x Hunter (2011)
# 6131        Boku no Hero Academia 2nd Season
# 3111                            Angel Beats!
# 5224             Shingeki no Kyojin Season 2
# 1340         Code Geass: Hangyaku no Lelouch
# 2641                               Toradora!
# 1463                      Naruto: Shippuuden
# 4789                                Noragami
# 3831                             Mirai Nikki
# ...

# %%
df_popular_anime_full_2[df_popular_anime_full_2['English name']=='Unknown'][['Name','English name','weighted_score']]
# Out:
#                                                    Name English name  \
# 5                                          Eyeshield 21      Unknown
# 7                            Hungry Heart: Wild Striker      Unknown
# 8                                Initial D Fourth Stage      Unknown
# 19                                               Zipang      Unknown
# 35                                    Appleseed (Movie)      Unknown
# ...                                                 ...          ...
# 8095                      Kimetsu Gakuen: Valentine-hen      Unknown
# 8098                      Kimetsu no Yaiba: Yuukaku-hen      Unknown
# 8102                     Hataraku Maou-sama! 2nd Season      Unknown
# 8104  Maou Gakuin no Futekigousha: Shijou Saikyou no...      Unknown
# 8105  Maou Gakuin no Futekigousha: Shijou Saikyou no...      Unknown
#
#       weighted_score
# 5       74133.470292
# 7       10238.794048
# 8       58968.570578
# 19       8329.754210
# 35      32573.049129
# ...

# %%
df_popular_anime_full['Source']
# Out:
# 0           Original
# 1           Original
# 2              Manga
# 3           Original
# 4              Manga
#             ...
# 8109           Manga
# 8110        Original
# 8111     Light novel
# 8112           Manga
# 8113    Visual novel
# Name: Source, Length: 8114, dtype: object

# %%
df_popular_anime_full.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes', 'Aired',
#        'Premiered', 'Producers', 'Licensors', 'Studios', 'Source', 'Duration',
#        'Rating', 'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'sypnopsis', 'summary', 'token_counts', 'embedding',
#        'weighted_average', 'normalized_weight', 'normalized_members',
#        'weighted_score', 'English name'],
#       dtype='object')

# %%
df_popular_anime_full_3 = df_popular_anime_full_2.drop(['Aired','Premiered', 'Producers', 'Licensors', 'Studios', 'Source'],axis=1).copy()

# %%
df_popular_anime_full_3
# Out:
#       MAL_ID                                               Name  Score  \
# 0          1                                       Cowboy Bebop   8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira   8.39
# 2          6                                             Trigun   8.24
# 3          7                                 Witch Hunter Robin   7.27
# 5         15                                       Eyeshield 21   7.95
# ...      ...                                                ...    ...
# 8098   47778                      Kimetsu no Yaiba: Yuukaku-hen   0.00
# 8102   48413                     Hataraku Maou-sama! 2nd Season   0.00
# 8103   48417  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
# 8104   48417  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
# 8105   48417  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
#
#                                                  Genres   Type Episodes  \
# ...

# %%
df_popular_anime_full_3[df_popular_anime_full_3['English name']=='Naruto']
# Out:
#     MAL_ID    Name  Score                                             Genres  \
# 10      20  Naruto   7.91  Action, Adventure, Comedy, Super Power, Martia...
#
#    Type Episodes         Duration                     Rating Ranked  \
# 10   TV      220  23 min. per ep.  PG-13 - Teens 13 or older  660.0
#
#     Popularity  ...  Completed  \
# 10           8  ...    1462223
#
#                                             sypnopsis  \
# 10  oments prior to Naruto Uzumaki's birth, a huge...
#
#                                               summary  token_counts  \
# 10  Genre: Action, Adventure, Comedy, Super Power,...           177
#
#                                             embedding weighted_average  \
# 10  [0.012714277021586895, -0.01993190310895443, -...         7.306514
#
#     normalized_weight normalized_members  weighted_score  English name
# 10           7.306514            1830540   915273.653257        Naruto
#
# [1 rows x 23 columns]

# %% [markdown]
# # Building content filtering based recommender system

# %%
import ast

# %%
string_list = '[889,23,932684,839094,279402,290943]'

# %%
normal_list = ast.literal_eval(string_list)

# %%
normal_list
# Out:
# [889, 23, 932684, 839094, 279402, 290943]

# %%
from sklearn.metrics.pairwise import sigmoid_kernel # importing the sigmoid_kernel function

# %%
embed_matrix = np.vstack(df_popular_anime_full_3['embedding'].values[0])

# %%
#embed_matrix[0][0]

# %%
embed_matrix = ast.literal_eval(embed_matrix[0][0])

# %%
#embed_matrix

# %%
sig = sigmoid_kernel(np.asarray(embed_matrix).reshape(-1, 1), np.asarray(embed_matrix).reshape(-1, 1)) # compute the sigmoid kernel

# %%
sig
# Out:
# array([[0.76163554, 0.76141983, 0.76149934, ..., 0.76157498, 0.76156283,
#         0.76154915],
#        [0.76141983, 0.76232696, 0.76199303, ..., 0.76167489, 0.76172602,
#         0.76178357],
#        [0.76149934, 0.76199303, 0.76181121, ..., 0.76163808, 0.7616659 ,
#         0.76169721],
#        ...,
#        [0.76157498, 0.76167489, 0.76163808, ..., 0.76160304, 0.76160867,
#         0.76161501],
#        [0.76156283, 0.76172602, 0.7616659 , ..., 0.76160867, 0.76161786,
#         0.76162821],
#        [0.76154915, 0.76178357, 0.76169721, ..., 0.76161501, 0.76162821,
#         0.76164308]])

# %%
sig[0]
# Out:
# 1536

# %%
len(sig)
# Out:
# 1536

# %%
df_popular_anime_full_3['embedding'] = df_popular_anime_full_3['embedding'].apply(lambda x: ast.literal_eval(x))

# %%
df_popular_anime_full_3['embedding'] = df_popular_anime_full_3['embedding'].apply(lambda x: np.array(x).reshape(1,-1))

# %%
df_popular_anime_full_3['embedding'][0]
# Out:
# array([[ 0.00992737, -0.04179946, -0.02273838, ..., -0.00459992,
#         -0.00751332, -0.01079378]])

# %%
df_recommendation = df_popular_anime_full_3.copy()

# %%
df_recommendation = df_recommendation.reset_index().drop(['index','MAL_ID'],axis=1).copy()

# %%
df_recommendation
# Out:
#                                                    Name  Score  \
# 0                                          Cowboy Bebop   8.78
# 1                       Cowboy Bebop: Tengoku no Tobira   8.39
# 2                                                Trigun   8.24
# 3                                    Witch Hunter Robin   7.27
# 4                                          Eyeshield 21   7.95
# ...                                                 ...    ...
# 4052                      Kimetsu no Yaiba: Yuukaku-hen   0.00
# 4053                     Hataraku Maou-sama! 2nd Season   0.00
# 4054  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
# 4055  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
# 4056  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
#
#                                                  Genres   Type Episodes  \
# 0       Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# ...

# %%
#df_recommendation.to_csv('final_recommendation_df.csv',index=False)

# %%
anime_name = 'Cowboy Bebop'

# %%
cb_embed = df_recommendation[df_recommendation['Name']==anime_name]['embedding'].values[0][0]

# %%
naruto_embed = df_recommendation[df_recommendation['Name']=='Naruto']['embedding'].values[0][0]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(cb_embed.reshape(1,-1),naruto_embed.reshape(1,-1))[0][0]
# Out:
# 0.8003781087275386

# %%
df_recommendation['embedding'][3]
# Out:
# array([[ 0.02243782, -0.02586121, -0.01755484, ..., -0.00107644,
#         -0.03290703, -0.01393241]])

# %%
cos_dist = []
for i in range(len(df_recommendation)):
    cos_dist.append(cosine_similarity(cb_embed.reshape(1,-1), df_recommendation['embedding'][i])[0][0])

# %%
#cos_dist

# %%
df_rec = df_recommendation.copy()

# %%
df_rec['cos_similarity'] = cos_dist

# %%
df_rec.sort_values(['cos_similarity','weighted_score'],ascending=False)[['Name','English name','cos_similarity','weighted_score','Genres','Popularity','Score']].head(11)[1:]
# Out:
#                                   Name                  English name  \
# 1      Cowboy Bebop: Tengoku no Tobira        Cowboy Bebop:The Movie
# 1104   Cowboy Bebop: Yose Atsume Blues       Cowboy Bebop Session XX
# 2128  Cowboy Bebop: Ein no Natsuyasumi         Ein's Summer Vacation
# 441              Mujin Wakusei Survive                       Unknown
# 3711                         RobiHachi                     RobiHachi
# 558            Top wo Nerae! Gunbuster                     Gunbuster
# 580      Uchuu Kaizoku Captain Herlock  Space Pirate Captain Harlock
# 280          Seihou Bukyou Outlaw Star                   Outlaw Star
# 917                        Space Cobra         Space Adventure Cobra
# 1203          Tetsuwan Birdy Decode:02    Birdy the Mighty:Decode 02
#
#       cos_similarity  weighted_score  \
# 1           0.926767   136576.682896
# 1104        0.920479    17928.718931
# 2128        0.898137    10216.625393
# 441         0.883467    11476.853866
# ...

# %%
df_recommendation.columns
# Out:
# Index(['Name', 'Score', 'Genres', 'Type', 'Episodes', 'Duration', 'Rating',
#        'Ranked', 'Popularity', 'Members', 'Favorites', 'Watching', 'Completed',
#        'sypnopsis', 'summary', 'token_counts', 'embedding', 'weighted_average',
#        'normalized_weight', 'normalized_members', 'weighted_score',
#        'English name'],
#       dtype='object')

# %%
df_recommendation_2 = df_recommendation.drop(['Rating','Favorites', 'Watching', 'Completed','sypnopsis','Ranked','token_counts','weighted_average','normalized_weight', 'normalized_members'],axis=1).copy()

# %%
df_recommendation_2
# Out:
#                                                    Name  Score  \
# 0                                          Cowboy Bebop   8.78
# 1                       Cowboy Bebop: Tengoku no Tobira   8.39
# 2                                                Trigun   8.24
# 3                                    Witch Hunter Robin   7.27
# 4                                          Eyeshield 21   7.95
# ...                                                 ...    ...
# 4052                      Kimetsu no Yaiba: Yuukaku-hen   0.00
# 4053                     Hataraku Maou-sama! 2nd Season   0.00
# 4054  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
# 4055  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
# 4056  Maou Gakuin no Futekigousha: Shijou Saikyou no...   0.00
#
#                                                  Genres   Type Episodes  \
# 0       Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# ...

# %%
import re

# %%
s = 'Hello!!!--World.'
s = re.sub(r'[.,"\'-?:!;]', '', s)
s.strip()
# Out:
# 'HelloWorld'

# %%
def string_cleaner(s):
    s = s.lower()
    s = re.sub(r'[.,"\'-?:!;_|/><]', '', s)
    return s.strip()

# %%
string_cleaner('Haikyu!!')
# Out:
# 'haikyu'

# %%
df_recommendation_2['Name_cleaned'] = df_recommendation_2['Name'].apply(lambda x: string_cleaner(x))
df_recommendation_2['English_name_cleaned'] = df_recommendation_2['English name'].apply(lambda x: string_cleaner(x))

# %%
df_recommendation_2[df_recommendation_2['Name_cleaned']=='kuroko no basket']
# Out:
#                   Name  Score                           Genres Type Episodes  \
# 1814  Kuroko no Basket   8.15  Comedy, School, Shounen, Sports   TV       25
#
#              Duration  Popularity  Members  \
# 1814  24 min. per ep.         104   810207
#
#                                                 summary  \
# 1814  Genre: Comedy, School, Shounen, Sports and the...
#
#                                               embedding  weighted_score  \
# 1814  [[-0.006185698322951794, -0.029088962823152542...   405107.525717
#
#              English name      Name_cleaned English_name_cleaned
# 1814  Kuroko's Basketball  kuroko no basket   kurokos basketball

# %%
'kuroko no basket' in df_recommendation_2['Name_cleaned'].unique()
# Out:
# True

# %%
def give_anime_recommendation(name,df=df_recommendation_2):
    df = df_recommendation_2.copy()
    cleaned_name = string_cleaner(name)
    #name_lower = name.lower()
    if name in  df['Name'].unique():
        required_embedding = df[df['Name']==name]['embedding'].values[0][0]
        cos_dist = []
        for i in range(len(df_recommendation)):
            cos_dist.append(cosine_similarity(required_embedding.reshape(1,-1), df['embedding'][i])[0][0])
        df['cos_similarity'] = cos_dist
        return df.sort_values('cos_similarity',ascending=False)[['Name','English name','cos_similarity','weighted_score','Type','Genres','Popularity','Score']].head(50)[1:].sort_values('weighted_score',ascending=False).head(10)[1:].sort_values('Score',ascending=False)
    
    elif name in  df['English name'].unique():
        required_embedding = df[df['English_name_lower']==name.lower()]['embedding'].values[0][0]
        cos_dist = []
        for i in range(len(df_recommendation)):
            cos_dist.append(cosine_similarity(required_embedding.reshape(1,-1), df['embedding'][i])[0][0])
        df['cos_similarity'] = cos_dist
        return df.sort_values('cos_similarity',ascending=False)[['Name','English name','cos_similarity','weighted_score','Type','Genres','Popularity','Score']].head(50)[1:].sort_values('weighted_score',ascending=False).head(10)[1:].sort_values('Score',ascending=False)
    
    elif cleaned_name in  df['Name_cleaned'].unique():
        required_embedding = df[df['Name_cleaned']==cleaned_name]['embedding'].values[0][0]
        cos_dist = []
        for i in range(len(df_recommendation)):
            cos_dist.append(cosine_similarity(required_embedding.reshape(1,-1), df['embedding'][i])[0][0])
        df['cos_similarity'] = cos_dist
        return df.sort_values('cos_similarity',ascending=False)[['Name','English name','cos_similarity','weighted_score','Type','Genres','Popularity','Score']].head(50)[1:].sort_values('weighted_score',ascending=False).head(10)[1:].sort_values('Score',ascending=False)
    
    elif cleaned_name in  df['English_name_cleaned'].unique():
        required_embedding = df[df['English_name_cleaned']==cleaned_name]['embedding'].values[0][0]
        cos_dist = []
        for i in range(len(df_recommendation)):
            cos_dist.append(cosine_similarity(required_embedding.reshape(1,-1), df['embedding'][i])[0][0])
        df['cos_similarity'] = cos_dist
        return df.sort_values('cos_similarity',ascending=False)[['Name','English name','cos_similarity','weighted_score','Type','Genres','Popularity','Score']].head(50)[1:].sort_values('weighted_score',ascending=False).head(10)[1:].sort_values('Score',ascending=False)   
    
    
    else:
        return 'Sorry!! Anime Not in the database.'

# %%
give_anime_recommendation('Kuroko no basket')
# Out:
#                                                    Name  \
# 2991  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...
# 2645                            Haikyuu!! Second Season
# 3917                   Haikyuu!!: To the Top 2nd Season
# 131                                           Slam Dunk
# 3733                              Haikyuu!!: To the Top
# 2483                        Kuroko no Basket 3rd Season
# 2114                        Kuroko no Basket 2nd Season
# 2202                                     Diamond no Ace
# 1932                                    Little Busters!
#
#                English name  cos_similarity  weighted_score Type  \
# 2991    Haikyu!! 3rd Season        0.886074   363624.372788   TV
# 2645    Haikyu!! 2nd Season        0.883764   437079.290006   TV
# 3917                Unknown        0.878824   177957.266655   TV
# 131               Slam Dunk        0.891198   100605.755660   TV
# 3733                Unknown        0.894545   235108.172556   TV
# ...

# %%
give_anime_recommendation('Dragon Ball super')
# Out:
#                                                    Name  \
# 3474                     Dragon Ball Super Movie: Broly
# 167                                         Dragon Ball
# 1290                                    Dragon Ball Kai
# 2404                             Dragon Ball Kai (2014)
# 542   Dragon Ball Z Movie 12: Fukkatsu no Fusion!! G...
# 1993               Dragon Ball Z Movie 14: Kami to Kami
# 538   Dragon Ball Z Movie 08: Moetsukiro!! Nessen, R...
# 2531            Dragon Ball Z Movie 15: Fukkatsu no "F"
# 168                                      Dragon Ball GT
#
#                                           English name  cos_similarity  \
# 3474                           Dragon Ball Super:Broly        0.931880
# 167                                        Dragon Ball        0.903718
# 1290                                 Dragon Ball Z Kai        0.929940
# 2404              Dragon Ball Z Kai:The Final Chapters        0.932638
# ...

# %%
give_anime_recommendation('Haikyu')
# Out:
#                                                    Name  \
# 2991  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...
# 2645                            Haikyuu!! Second Season
# 3917                   Haikyuu!!: To the Top 2nd Season
# 131                                           Slam Dunk
# 3733                              Haikyuu!!: To the Top
# 2114                        Kuroko no Basket 2nd Season
# 3227                                 Ballroom e Youkoso
# 1814                                   Kuroko no Basket
# 2194                                              Free!
#
#                    English name  cos_similarity  weighted_score Type  \
# 2991        Haikyu!! 3rd Season        0.910643   363624.372788   TV
# 2645        Haikyu!! 2nd Season        0.923064   437079.290006   TV
# 3917                    Unknown        0.893547   177957.266655   TV
# 131                   Slam Dunk        0.890889   100605.755660   TV
# ...

# %%
give_anime_recommendation('Demon Slayer')
# Out:
# 'Sorry!! Anime Not in the database.'

# %%
give_anime_recommendation('Death Note')
# Out:
#                                  Name  \
# 176                   Detective Conan
# 1057                       Soul Eater
# 3054                  Ajin 2nd Season
# 933   Kara no Kyoukai 1: Fukan Fuukei
# 1720                      Mirai Nikki
# 1716          Persona 4 the Animation
# 1969                                K
# 2107              Mirai Nikki: Redial
# 1187                       ChäoS;HEAd
#
#                                           English name  cos_similarity  \
# 176                                        Case Closed        0.862029
# 1057                                        Soul Eater        0.864925
# 3054                                           Unknown        0.862139
# 933   the Garden of sinners Chapter 1:Overlooking View        0.864696
# 1720                                  The Future Diary        0.871934
# 1716                           Persona 4 the Animation        0.864503
# 1969                                                 K        0.865357
# ...

# %%
give_anime_recommendation('Monster')
# Out:
#                            Name             English name  cos_similarity  \
# 1449     Yojouhan Shinwa Taikei        The Tatami Galaxy        0.865263
# 2760    Boku dake ga Inai Machi                   ERASED        0.869630
# 651             NHK ni Youkoso!    Welcome to the N.H.K.        0.863836
# 1739         Mawaru Penguindrum              Penguindrum        0.858852
# 550   Higurashi no Naku Koro ni            When They Cry        0.870495
# 2160                Golden Time              Golden Time        0.858466
# 1463     Highschool of the Dead  High School of the Dead        0.859925
# 2588             Tokyo Ghoul √A           Tokyo Ghoul √A        0.867132
# 1187                 ChäoS;HEAd               ChäoS;HEAd        0.871589
#
#       weighted_score Type                                             Genres  \
# 1449   153783.289481   TV            Mystery, Comedy, Psychological, Romance
# 2760   679563.511763   TV       Mystery, Psychological, Supernatural, Seinen
# ...

# %%
#df_recommendation_2.to_csv('df_recommendation_2.csv',index=False)

# %%
def give_anime_recommendation_2(name,df=df_recommendation_2):
    df = df_recommendation_2.copy()
    cleaned_name = string_cleaner(name)
    #name_lower = name.lower()
    if name in  df['Name'].unique():
        required_embedding = df[df['Name']==name]['embedding'].values[0][0]
        
    elif name in  df['English name'].unique():
        required_embedding = df[df['English name']==name]['embedding'].values[0][0]
        
    elif cleaned_name in  df['Name_cleaned'].unique():
        required_embedding = df[df['Name_cleaned']==cleaned_name]['embedding'].values[0][0]
        
    elif cleaned_name in  df['English_name_cleaned'].unique():
        required_embedding = df[df['English_name_cleaned']==cleaned_name]['embedding'].values[0][0]
        
    else:
        return 'Sorry!! Anime Not in the database.'
    
    cos_dist = []
    for i in range(len(df_recommendation)):
        cos_dist.append(cosine_similarity(required_embedding.reshape(1,-1), df['embedding'][i])[0][0])
    df['cos_similarity'] = cos_dist
    return df.sort_values('cos_similarity',ascending=False)[['Name','English name','cos_similarity','weighted_score','Type','Genres','Popularity','Score']].head(20)[1:].sort_values('weighted_score',ascending=False).head(10).sort_values('Score',ascending=False)

# %%
give_anime_recommendation_2('Naruto')
# Out:
#                                                    Name  \
# 802                                  Naruto: Shippuuden
# 2112                         The Last: Naruto the Movie
# 1935         Naruto: Shippuuden Movie 6 - Road to Ninja
# 2634                           Boruto: Naruto the Movie
# 1475        Naruto: Shippuuden Movie 4 - The Lost Tower
# 919                          Naruto: Shippuuden Movie 1
# 1141                Naruto: Shippuuden Movie 2 - Kizuna
# 306   Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shin...
# 552   Naruto Movie 2: Dai Gekitotsu! Maboroshi no Ch...
# 3215                    Boruto: Naruto Next Generations
#
#                                           English name  cos_similarity  \
# 802                                   Naruto:Shippuden        0.954575
# 2112                         The Last:Naruto the Movie        0.922053
# 1935                    Road to Ninja:Naruto the Movie        0.933485
# ...

# %%
give_anime_recommendation_2('Haikyu')
# Out:
#                                                    Name         English name  \
# 2991  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...  Haikyu!! 3rd Season
# 2645                            Haikyuu!! Second Season  Haikyu!! 2nd Season
# 3917                   Haikyuu!!: To the Top 2nd Season              Unknown
# 131                                           Slam Dunk            Slam Dunk
# 3733                              Haikyuu!!: To the Top              Unknown
# 1814                                   Kuroko no Basket  Kuroko's Basketball
# 3670                    Wotaku ni Koi wa Muzukashii OVA              Unknown
# 3861                            Haikyuu!!: Riku vs. Kuu              Unknown
# 2529                             Haikyuu!!: Lev Genzan!              Unknown
# 3527                                      Ahiru no Sora              Unknown
#
#       cos_similarity  weighted_score Type  \
# 2991        0.910643   363624.372788   TV
# ...

# %%
give_anime_recommendation_2('Death Note')
# Out:
#                                             Name  \
# 1218   Kara no Kyoukai 7: Satsujin Kousatsu (Go)
# 1083         Kara no Kyoukai 3: Tsuukaku Zanryuu
# 1136             Kara no Kyoukai 4: Garan no Dou
# 1082  Kara no Kyoukai 2: Satsujin Kousatsu (Zen)
# 984                          Death Note: Rewrite
# 1720                                 Mirai Nikki
# 2107                         Mirai Nikki: Redial
# 912                                  Zombie-Loan
# 2720                                 ChäoS;Child
# 1187                                  ChäoS;HEAd
#
#                                            English name  cos_similarity  \
# 1218  the Garden of sinners Chapter 7:Murder Specula...        0.877609
# 1083  the Garden of sinners Chapter 3:Remaining Sens...        0.880705
# 1136  the Garden of sinners Chapter 4:The Hollow Shrine        0.882506
# 1082  the Garden of sinners Chapter 2:Murder Specula...        0.880647
# ...

# %%
give_anime_recommendation_2("Kuroko's Basketball")
# Out:
#                                           Name                  English name  \
# 2483               Kuroko no Basket 3rd Season         Kuroko's Basketball 3
# 2114               Kuroko no Basket 2nd Season         Kuroko's Basketball 2
# 2762  Kuroko no Basket: Saikou no Present Desu                       Unknown
# 2842       Kuroko no Basket Movie 4: Last Game                       Unknown
# 11                         Tennis no Ouji-sama          The Prince of Tennis
# 2117                 Kuroko no Basket: Tip Off   Kuroko's Basketball Special
# 2029                  Kuroko no Basket NG-shuu  Kuroko's Basketball Specials
# 2247  Kuroko no Basket: Baka ja Katenai no yo!       Kuroko's Basketball OVA
# 3527                             Ahiru no Sora                       Unknown
# 1713                                Ro-Kyu-Bu!       Ro-Kyu-Bu ~ Fast Break!
#
#       cos_similarity  weighted_score     Type  \
# 2483        0.956347   253236.644190       TV
# ...
